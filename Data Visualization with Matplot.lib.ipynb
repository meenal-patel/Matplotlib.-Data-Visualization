# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
month = ["jan","feb","mar","apr","may","jun","jul"]
sales = [2300,7568,3644,5657,2346,9870,2345]

# %%
plt.figure(figsize=(8,6))
plt.plot(month,sales)
plt.xlabel("month")
plt.ylabel("sales")
plt.title("Sales Data", size=22)
# Out:
# Text(0.5, 1.0, 'Sales Data')

# %%
import pandas as pd

# %%
data=pd.read_csv("Cars.csv")

# %%
data
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
data.groupby(by="VOL")["MPG"].mean().head()
# Out:
# VOL
# 50    37.908979
# 86    33.051823
# 88    36.555735
# 89    45.343001
# 91    42.789909
# Name: MPG, dtype: float64

# %%
import seaborn as sns

# %%
sns.countplot(x="VOL",data=data)
# Out:
# <AxesSubplot:xlabel='VOL', ylabel='count'>

# %%
sns.histplot(data=data,x="MPG")
# Out:
# <AxesSubplot:xlabel='MPG', ylabel='Count'>

# %%
data['VOL'].value_counts()
# Out:
# 50     9
# 92     8
# 89     7
# 101    7
# 99     4
# 113    4
# 107    3
# 86     3
# 103    2
# 88     2
# 129    2
# 123    2
# 115    2
# 111    2
# 94     2
# 124    2
# 114    2
# 91     2
# 98     1
# 121    1
# 117    1
# 160    1
# 132    1
# 135    1
# 112    1
# 127    1
# 104    1
# 131    1
# 116    1
# 96     1
# 97     1
# 102    1
# 106    1
# 119    1
# Name: VOL, dtype: int64

# %%
plt.figure(figsize=(14,10))
plt.pie(x=data['VOL'].value_counts(),)

plt.show()

# %% [markdown]
# ## Bivariatre Analysis

# %%
sns.scatterplot(x='MPG',y='WT',data=data)
plt.figure(figsize=(30,20))
plt.show()

# %%
DATA = pd.read_csv('E:\\Users\\Meenal Patel\\Desktop\\Assignments\\1\\Q7.csv')
DATA
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
plt.figure(figsize=(14,10))
plt.pie(x=DATA['Unnamed: 0'].value_counts(),labels=DATA['Unnamed: 0'],autopct='%.2f')

plt.show()

# %%
def plot(df):
    plt.figure(figsize=(14,10))
    #pie = plt.pie(x=df['Unnamed: 0'].value_counts(),labels=df['Unnamed: 0'],autopct='%.2f')
    count = sns.countplot(x="Unnamed: 0",data=df)
    plt.show()

# %%
plot(DATA)

# %%
def nikhil(a):
    c = a+10
    return c

# %%
nikhil(2)
# Out:
# 12

# %%
plt.boxplot(data=DATA,x='Points')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24c3e4456a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24c3e445d00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24c3e4453d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24c3e44f220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24c3e44f4f0>],
#  'means': []}

# %%
data = DATA

# %%
for i in data:
    #print(i)  # column names
    for j in data[i]:
        print(j)
        #x=input()
# Out:
# Mazda RX4
# Mazda RX4 Wag
# Datsun 710
# Hornet 4 Drive
# Hornet Sportabout
# Valiant
# Duster 360
# Merc 240D
# Merc 230
# Merc 280
# Merc 280C
# Merc 450SE
# Merc 450SL
# Merc 450SLC
# Cadillac Fleetwood
# Lincoln Continental
# Chrysler Imperial
# Fiat 128
# Honda Civic
# Toyota Corolla
# Toyota Corona
# Dodge Challenger
# AMC Javelin
# Camaro Z28
# Pontiac Firebird
# Fiat X1-9
# Porsche 914-2
# Lotus Europa
# Ford Pantera L
# Ferrari Dino
# Maserati Bora
# Volvo 142E
# 3.9
# 3.9
# 3.85
# 3.08
# 3.15
# 2.76
# 3.21
# 3.69
# 3.92
# 3.92
# 3.92
# 3.07
# 3.07
# 3.07
# 2.93
# 3.0
# 3.23
# 4.08
# 4.93
# 4.22
# 3.7
# 2.76
# 3.15
# 3.73
# 3.08
# 4.08
# 4.43
# 3.77
# 4.22
# 3.62
# 3.54
# 4.11
# 2.62
# 2.875
# 2.32
# 3.215
# 3.44
# 3.46
# 3.57
# 3.19
# 3.15
# 3.44
# 3.44
# 4.07
# 3.73
# 3.78
# 5.25
# 5.424
# 5.345
# 2.2
# 1.615
# 1.835
# 2.465
# 3.52
# 3.435
# 3.84
# 3.845
# 1.935
# 2.14
# 1.513
# 3.17
# 2.77
# 3.57
# 2.78
# 16.46
# 17.02
# 18.61
# 19.44
# 17.02
# 20.22
# 15.84
# 20.0
# ...

# %%
plt.figure(figsize=(12,10))
plt.title('pointsvsscore')
sns.barplot(x='Points',y='Score',data=DATA,)
# Out:
# <AxesSubplot:title={'center':'pointsvsscore'}, xlabel='Points', ylabel='Score'>

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(data=DATA)
plt.show()
